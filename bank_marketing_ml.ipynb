# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bank.csv')

# %%
df.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
df.shape
# Out:
# (4521, 1)

# %%
df = pd.read_csv('bank.csv',sep=';') # re.load file using ";" separator

# %%
df.shape
# Out:
# (4521, 17)

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df['y'].value_counts() # target column
# Out:
# y
# no     4000
# yes     521
# Name: count, dtype: int64

# %%
# seprating features ( X ) and target ( y )
X = df.drop('y', axis=1)
y = df['y']

# %%
X.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# dtype: object

# %%
# category vs numerical 

cat_col = X.select_dtypes(include='object').columns
num_col = X.select_dtypes(include='int64').columns

# %%
num_col
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
# Encoding

X_encoded = pd.get_dummies(X, columns=cat_col, drop_first=True)

# %%
X_encoded.shape

# each category is in now a converted into yes/no  columna
# Out:
# (4521, 42)

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
X_encoded.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous  job_blue-collar  \
# 0   30     1787   19        79         1     -1         0            False
# 1   33     4789   11       220         1    339         4            False
# 2   35     1350   16       185         1    330         1            False
# 3   30     1476    3       199         4     -1         0            False
# 4   59        0    5       226         1     -1         0             True
#
#    job_entrepreneur  job_housemaid  ...  month_jul  month_jun  month_mar  \
# 0             False          False  ...      False      False      False
# 1             False          False  ...      False      False      False
# 2             False          False  ...      False      False      False
# 3             False          False  ...      False       True      False
# 4             False          False  ...      False      False      False
#
#    month_may  month_nov  month_oct  month_sep  poutcome_other  \
# ...

# %%
from sklearn.model_selection import train_test_split # importiing train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
    
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_Scaled = scaler.fit_transform(X_train)
X_test_Scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=500)
model.fit(X_train_Scaled, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
y_pred = model.predict(X_test_Scaled)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[776,  25],
#        [ 73,  31]])

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n          no       0.91      0.97      0.94       801\n         yes       0.55      0.30      0.39       104\n\n    accuracy                           0.89       905\n   macro avg       0.73      0.63      0.66       905\nweighted avg       0.87      0.89      0.88       905\n'

# %%
# Recall : Out of all actual 'NO' customers how many did we correcltly identify
# Correctly predicted NO : 777
# Actual NO : 801 
# So recall is very high. Ours model almost never misses who would say O.

# Precision : when the model says 'NO' how often is it correct.
# precision score = 0.91
# meaning almost of the time when we predict no we are right

# F1 score : Balance between precision and recall
# F1 score = 0.94
# Meaning the model is exactly good at identify customers who will say NO

# %%
# For YES

# support is 104 
# meaning onlt 104 customers actuaaly said yes

# Recall : Out of customers who actuaaly said YES, and how many did we identify
# Recall Score = 0.29
# MEaning we only identify 29% of actually intrested customers 
# 71% were missed.

# Acrtual YES = 104
# YES predication = 30

# The model is missing almost customers who would actually say YES

# Precsion : When the model say YES, how often is it correct.
# precision score = 0.56
# Meaning out of all customers we contacted thinking they would say yes onl 56% actually did.

#F1 score = 038
# Because recall is very poor.

# %%
# Accuracy = 0.89
# 89% loks good but the model is not working properly.
# most customers say NO
# predication NO often gives high accuracy 
# Data is imbalanced.
# High accuracy does not mean good model

# %%
# macro avg   prediaction = 0.73  recall = 0.63  F1 score = 0.66

# Treats NO and YES equally
# Reward poor performance on YES

# %%
# weighted avg        precision=0.87      recall=0.89      f1-score=0.88 

# Gives more weightage to majority class i.e NO

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='y', data=df)
plt.title('Target Distribution (y)')
plt.xlabel("Subscribptions")
plt.ylabel("Count")

plt.savefig("Visualization/target_distribution.png")

# %%
# Age Distribution 

plt.figure(figsize=(8,4))
plt.hist(df['age'], bins=20, edgecolor='black', alpha=0.6) 
plt.title("Age Distribution") 
plt.xlabel("Age")
plt.ylabel("Count")
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

plt.savefig("Visualization/Age Distribution.png")

# %%
# Balance Distribution

plt.figure(figsize=(8,4))
plt.hist(df['balance'], bins=20, edgecolor='black', alpha=0.6) 
plt.title("Balance Distribution") 
plt.xlabel("Balance")
plt.ylabel("Count")
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

plt.savefig("Visualization/Balance Distribution.png")

# %%
# duration Distribution

plt.figure(figsize=(8,4))
plt.hist(df['duration'], bins=20, edgecolor='black', alpha=0.6) 
plt.title("Duration Distribution") 
plt.xlabel("Duratiin")
plt.ylabel("Count")
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

plt.savefig("Visualization/Duration Distribution.png")
